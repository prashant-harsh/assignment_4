# %% [markdown]
# The Adult Income dataset
# Description Title of dataset: adult.csv
#
# Sources:
#
# Original owners of database - US Census Bureau
#
# Donor of database - Ronny Kohavi and Barry Becker
#
# Date received - 05/19/96 Number of Instances
#
# 48842 instances, mix of continuous and discrete (train=32561, test=16281)
#
# 45222 if instances with unknown values are removed (train=30162, test=15060)
#
# Split into train-test using MLC++ GenCVFiles (2/3, 1/3 random). Number of Attributes/Fearures/Columns
#
# 6 continuous, 8 nominal attributes. Attribute Information/Fearures/Columns
#
# age: continuous.
#
# workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
#
# fnlwgt: continuous.
#
# education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# education-num: continuous.
#
# marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# sex: Female, Male.
#
# capital-gain: continuous.
#
# capital-loss: continuous.
#
# hours-per-week: continuous.
#
# native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
#
# income: >50K, <=50K Missing Values:
#
# 7% rows have missing values

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/adult.csv')

# %%
print(df.shape)
print("row ->",df.shape[0])
print("column ->",df.shape[1])
# Out:
# (48842, 15)
# row -> 48842
# column -> 15

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
#find misssing value

# %%
miss_val = ['n/a', '-', '?']

df = pd.read_csv('data/adult.csv', na_values = miss_val)

df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False       True   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
#remove column fnlwgt to adult dataset

# %%
df=df.drop('fnlwgt',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
# age                48842 non-null int64
# workclass          46043 non-null object
# education          48842 non-null object
# educational-num    48842 non-null int64
# marital-status     48842 non-null object
# occupation         46033 non-null object
# relationship       48842 non-null object
# race               48842 non-null object
# gender             48842 non-null object
# capital-gain       48842 non-null int64
# capital-loss       48842 non-null int64
# hours-per-week     48842 non-null int64
# native-country     47985 non-null object
# income             48842 non-null object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
dumy=len(df.index)
dumy
# Out:
# 48842

# %%
df=df.dropna(axis=0,how='any')

# %%
# remove row percentage

# %%
r_pct=len(df)/dumy*100
r_pct
# Out:
# 92.58834609557348

# %%
df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 5   34    Private          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (45222, 14)

# %%
df.describe()
# Out:
#                 age  educational-num  capital-gain  capital-loss  \
# count  45222.000000     45222.000000  45222.000000  45222.000000
# mean      38.547941        10.118460   1101.430344     88.595418
# std       13.217870         2.552881   7506.430084    404.956092
# min       17.000000         1.000000      0.000000      0.000000
# 25%       28.000000         9.000000      0.000000      0.000000
# 50%       37.000000        10.000000      0.000000      0.000000
# 75%       47.000000        13.000000      0.000000      0.000000
# max       90.000000        16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    45222.000000
# mean        40.938017
# std         12.007508
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45222 entries, 0 to 48841
# Data columns (total 14 columns):
# age                45222 non-null int64
# workclass          45222 non-null object
# education          45222 non-null object
# educational-num    45222 non-null int64
# marital-status     45222 non-null object
# occupation         45222 non-null object
# relationship       45222 non-null object
# race               45222 non-null object
# gender             45222 non-null object
# capital-gain       45222 non-null int64
# capital-loss       45222 non-null int64
# hours-per-week     45222 non-null int64
# native-country     45222 non-null object
# income             45222 non-null object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# # missing value pattern observed by using different function of missingno library

# %% [markdown]
# # heatmap

# %%
import pandas as pd 
import missingno as msno 
  
# Load the dataset 
df = pd.read_csv("data/adult.csv") 
df.head()
  
# missing values by bar chart 
msno.heatmap(df) 
plt.figure()
# Out:
# E:\python\lib\site-packages\seaborn\matrix.py:287: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# E:\python\lib\site-packages\seaborn\matrix.py:287: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-bcd1dd4ae27c> in <module>
#       8 # missing values by bar chart
#       9 msno.heatmap(df)
# ---> 10 plt.figure()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # BAR CHART

# %%
import pandas as pd 
import missingno as msno 
  
# Load the dataset 
df = pd.read_csv("data/adult.csv") 
df.head()
  
# missing values by bar chart 
msno.bar(df) 
plt.figure()

# %% [markdown]
# # MATRIX

# %%
import pandas as pd 
import missingno as msno 
  
# Load the dataset 
df = pd.read_csv("data/adult.csv") 
df.head()
  
# missing values by matrix 
msno.matrix(df) 
plt.figure()

# %% [markdown]
# # Univariate Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/adult.csv')

print(df.shape)

df.head()

# %%
df.info()

# %% [markdown]
# # pdf of numeric column of adult.csv dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['age'])

# %%
#pdf of age column is decreaseses

# %%
sns.distplot(df['educational-num'])

# %%
# educational-num column increase

# %%
sns.distplot(df['capital-gain'])

# %%
# capital gain column decrese

# %%
sns.distplot(df['capital-loss'])

# %%
# capital loss column decrease

# %%
sns.distplot(df['hours-per-week'])

# %%
# hours-per-week column guossion distribution

# %% [markdown]
# # histogram of adult dataset

# %%
plt.hist(df['age'])
plt.show()

# %%
# age column increase

# %%
plt.hist(df['educational-num'])
plt.show()

# %%
# educational-num column decrese

# %%
plt.hist(df['capital-gain'])
plt.show()

# %%
#capital-gain parellel to y axis

# %%
plt.hist(df['capital-loss'])
plt.show()

# %%
#capital-gain parellel to y axis

# %%
plt.hist(df['hours-per-week'])
plt.show()

# %%
#hours-per-week column is gouisson distribution

# %%
 #frequency distribution of each categorical Variable/Column

# %%
plt.hist(df['workclass'])
plt.show()

# %%
# workclass column decrese

# %%
plt.hist(df['education'])
plt.show()

# %%
# education column decrese

# %%
plt.hist(df['marital-status'])
plt.show()

# %%
# marital-status column decrese

# %%
plt.hist(df['occupation'])
plt.show()

# %%
# occupation column is histogram

# %%
plt.hist(df['relationship'])
plt.show()

# %%
#relationship column is histogram

# %%
plt.hist(df['race'])
plt.show()

# %%
# race column is histogram

# %%
plt.hist(df['gender'])
plt.show()

# %%
# gender column is histogram

# %%
plt.hist(df['native-country'])
plt.show()

# %%
#nautive country  parellel to y axis

# %%
plt.hist(df['income'])
plt.show()

# %%
# income lie beetween <= 50  >50k

# %% [markdown]
# # boxplot of adult dataset

# %%
plt.boxplot(df['age'])
plt.show()

# %%
# outlier in age

# %%
plt.boxplot(df['educational-num'])
plt.show()

# %%
# outlier in educational-num

# %%
plt.boxplot(df['capital-gain'])
plt.show()

# %%
# outlier in capital-gain

# %%
plt.boxplot(df['capital-loss'])
plt.show()

# %%
# outlier in capital-loss

# %%
plt.boxplot(df['hours-per-week'])
plt.show()

# %%
# outlier in hours-per-week

# %% [markdown]
# #  countplot of adult dataset

# %%
sns.countplot(x='age', data=df, palette='Greens_d')

# %%
# decrease in age

# %%
sns.countplot(x='educational-num', data=df, palette='Greens_d')

# %%
#increase in educational-num

# %%
sns.countplot(x='capital-gain', data=df, palette='Greens_d')

# %%
# capital gain blank

# %%
sns.countplot(x='capital-loss', data=df, palette='Greens_d')

# %%
# capital loss blank

# %%
sns.countplot(x='hours-per-week', data=df, palette='Greens_d')

# %%
# hours-per week is gouisson distribution

# %% [markdown]
# # bivariate analysis

# %%
# Discover the relationships between numerical columns using->

# %% [markdown]
# # scatterplot

# %%
#for age column

# %%
sns.jointplot(x='age', y='age', data=df, kind = 'scatter')

# %%
# diagnal age

# %%
sns.jointplot(x='age', y='educational-num', data=df, kind = 'scatter')

# %%
# realtion between age and educational num

# %%
sns.jointplot(x='age', y='capital-gain', data=df, kind = 'scatter')

# %%
# relation between age and capital-gain

# %%
sns.jointplot(x='age', y='capital-loss', data=df, kind = 'scatter')

# %%
# relation between age and capital-loss

# %%
sns.jointplot(x='age', y='hours-per-week', data=df, kind = 'scatter')

# %%
# relation between ahe and hours-per week

# %%
#for educational -num

# %%
sns.jointplot(x='educational-num', y='age', data=df, kind = 'scatter')

# %%
# relation between educational-num and age

# %%
sns.jointplot(x='educational-num', y='educational-num', data=df, kind = 'scatter')

# %%
# educational- num diagnal

# %%
sns.jointplot(x='educational-num', y='capital-gain', data=df, kind = 'scatter')

# %%
#relation between educational-num and capital gain

# %%
sns.jointplot(x='educational-num', y='capital-loss', data=df, kind = 'scatter')

# %%
#relation between educational-num and capital loss

# %%
sns.jointplot(x='educational-num', y='hours-per-week', data=df, kind = 'scatter')

# %%
#relation between educational-num and hours-per-week

# %%
#for capital-gain column

# %%
sns.jointplot(x='capital-gain', y='age', data=df, kind = 'scatter')

# %%
#relation between capital-gain and age

# %%
sns.jointplot(x='capital-gain', y='educational-num', data=df, kind = 'scatter')

# %%
#relation between capital-gain and educational-num

# %%
sns.jointplot(x='capital-gain', y='capital-gain', data=df, kind = 'scatter')

# %%
# capital-gain diangal

# %%
sns.jointplot(x='capital-gain', y='capital-loss', data=df, kind = 'scatter')

# %%
#relation between capital-gain and capital-loss

# %%
sns.jointplot(x='capital-gain', y='hours-per-week', data=df, kind = 'scatter')

# %%
#relation between capital-gain and hours-per week

# %%
# for capital-loss column

# %%
sns.jointplot(x='capital-loss', y='age', data=df, kind = 'scatter')

# %%
#relation between capital-loss and age

# %%
sns.jointplot(x='capital-loss', y='educational-num', data=df, kind = 'scatter')

# %%
#relation between capital-loss and educational-num

# %%
sns.jointplot(x='capital-loss', y='capital-gain', data=df, kind = 'scatter')

# %%
# relation between capital-loss  and capital gain

# %%
sns.jointplot(x='capital-loss', y='capital-loss', data=df, kind = 'scatter')

# %%
# capital loss diagnal

# %%
sns.jointplot(x='capital-loss', y='hours-per-week', data=df, kind = 'scatter')

# %%
#relation between capital-loss and hours-per-week

# %%
# for hours-per-week column

# %%
sns.jointplot(x='hours-per-week', y='age', data=df, kind = 'scatter')

# %%
#relation between hours-per-week and age

# %%
sns.jointplot(x='hours-per-week', y='educational-num', data=df, kind = 'scatter')

# %%
#relation between hours-per-week and educational-num

# %%
sns.jointplot(x='hours-per-week', y='capital-gain', data=df, kind = 'scatter')

# %%
#relation between hours-per-week and capital-gain

# %%
sns.jointplot(x='hours-per-week', y='capital-loss', data=df, kind = 'scatter')

# %%
#relation between hours-per-week and capital-loss

# %%
sns.jointplot(x='hours-per-week', y='hours-per-week', data=df, kind = 'scatter')

# %%
# hours-per-week diagnal

# %% [markdown]
# # hexbin plots

# %%
#for age column

# %%
sns.jointplot(x='age', y='age', data=df, kind='hex', color='r')

# %%
#relation between age and age

# %%
sns.jointplot(x='age', y='educational-num', data=df, kind='hex', color='r')

# %%
#relation between age and educational-num

# %%
sns.jointplot(x='age', y='capital-gain', data=df, kind='hex', color='r')

# %%
#relation between age and capital-gain

# %%
sns.jointplot(x='age', y='capital-loss', data=df, kind='hex', color='r')

# %%
#relation between age and capital-loss

# %%
sns.jointplot(x='age', y='hours-per-week', data=df, kind='hex', color='r')

# %%
#relation between age and hours-per-week

# %%
#for educational-num

# %%
sns.jointplot(x='educational-num', y='age', data=df, kind='hex', color='r')

# %%
#relation between educational-num and age

# %%
sns.jointplot(x='educational-num', y='educational-num', data=df, kind='hex', color='r')

# %%
#relation between educational-num educational-num

# %%
sns.jointplot(x='educational-num', y='capital-gain', data=df, kind='hex', color='r')

# %%
#relation between educational-num and capital-gain

# %%
sns.jointplot(x='educational-num', y='capital-loss', data=df, kind='hex', color='r')

# %%
#relation between educational-num and capital-loss

# %%
sns.jointplot(x='educational-num', y='hours-per-week', data=df, kind='hex', color='r')

# %%
#relation between educational-num and hours-per-week

# %%
# for capita-gain

# %%
sns.jointplot(x='capital-gain', y='age', data=df, kind='hex', color='r')

# %%
#relation between capital-gain and age

# %%
sns.jointplot(x='capital-gain', y='educational-num', data=df, kind='hex', color='r')

# %%
#relation between capital-gain and educational-num

# %%
sns.jointplot(x='capital-gain', y='capital-gain', data=df, kind='hex', color='r')

# %%
#relation between capital-gain and capital-gain

# %%
sns.jointplot(x='capital-gain', y='capital-loss', data=df, kind='hex', color='r')

# %%
#relation between capital-gain and  capital-loss

# %%
sns.jointplot(x='capital-gain', y='hours-per-week', data=df, kind='hex', color='r')

# %%
#relation between capital-gain and hours-per-week

# %%
#for capital-loss

# %%
sns.jointplot(x='capital-loss', y='age', data=df, kind='hex', color='r')

# %%
#relation between capital-loss and age

# %%
sns.jointplot(x='capital-loss', y='educational-num', data=df, kind='hex', color='r')

# %%
#relation between capital-loss and educational-num

# %%
sns.jointplot(x='capital-loss', y='capital-gain', data=df, kind='hex', color='r')

# %%
#relation between capital-loss and  capital-gain

# %%
sns.jointplot(x='capital-loss', y='capital-loss', data=df, kind='hex', color='r')

# %%
#relation between capital-loss and capital-loss

# %%
sns.jointplot(x='capital-loss', y='hours-per-week', data=df, kind='hex', color='r')

# %%
#relation between capital-loss and hours-per-week

# %%
#for hours-per-week

# %%
sns.jointplot(x='hours-per-week', y='age', data=df, kind='hex', color='r')

# %%
#relation between hours-per-week and age

# %%
sns.jointplot(x='hours-per-week', y='educational-num', data=df, kind='hex', color='r')

# %%
#relation between hours-per-week and educational-num

# %%
sns.jointplot(x='hours-per-week', y='capital-gain', data=df, kind='hex', color='r')

# %%
#relation between hours-per-week and capital-gain

# %%
sns.jointplot(x='hours-per-week', y='capital-loss', data=df, kind='hex', color='r')

# %%
#relation between hours-per-week and capital-loss

# %%
sns.jointplot(x='hours-per-week', y='hours-per-week', data=df, kind='hex', color='r')

# %%
#relation between hours-per-week and hours-per-week

# %% [markdown]
# # pair plots

# %%
df = pd.read_csv('data/adult.csv')
df=df.drop('fnlwgt',axis=1)
sns.pairplot(df)

# %%
# pair plot of whole data fram and daignal show the relation of numeric column itself

# %%
df = pd.read_csv('data/adult.csv')
df=df.drop('fnlwgt',axis=1)
sns.pairplot(df, hue='age')
# Out:
# E:\python\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# E:\python\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# E:\python\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# E:\python\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# pair plot for age column

# %%
sns.pairplot(df, hue='educational-num')

# %%
#pair plot for educational-num column

# %%
sns.pairplot(df, hue='capital-gain')

# %%
# pair plot of capital-gain

# %%
sns.pairplot(df, hue='capital-loss')

# %%
# pair plot of capital-loss

# %%
sns.pairplot(df, hue='hours-per-week')

# %%
#pair plot of hours-per-week

# %%
#minmaxscaler

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy
import pandas
df=pd.read_csv('data/adult.csv')
scaler=MinMaxScaler()

# %%
#normalization
(pd.crosstab(df['age'],df['educational-num'],normalize='index'))*100
# Out:
# educational-num        1         2         3          4         5          6   \
# age
# 17               0.000000  0.000000  0.504202   0.840336  6.050420  33.277311
# 18               0.000000  0.000000  0.580046   0.696056  1.160093   6.148492
# 19               0.284900  0.284900  0.284900   1.234568  1.329535   2.279202
# 20               0.089847  0.089847  0.718778   0.539084  1.617251   1.707098
# 21               0.456204  0.091241  0.729927   0.729927  1.094891   2.281022
# ..                    ...       ...       ...        ...       ...        ...
# 86               0.000000  0.000000  0.000000   0.000000  0.000000   0.000000
# 87               0.000000  0.000000  0.000000   0.000000  0.000000   0.000000
# 88               0.000000  0.000000  0.000000  16.666667  0.000000   0.000000
# 89               0.000000  0.000000  0.000000   0.000000  0.000000  50.000000
# 90               0.000000  1.818182  0.000000   5.454545  1.818182   3.636364
#
# ...
